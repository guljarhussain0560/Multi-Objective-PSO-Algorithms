# %%
# !pip install pymoo numpy pandas matplotlib

# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from pymoo.core.population import Population
from pymoo.problems import get_problem
from pymoo.indicators.igd import IGD
from pymoo.indicators.hv import HV
from pymoo.algorithms.moo.nsga2 import RankAndCrowdingSurvival

# ============================================================
# MODEL 1: SGPSO (Stability-Guided PSO)
# ============================================================
# Publication-quality matplotlib settings
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 12,
    'axes.labelsize': 14,
    'axes.titlesize': 15,
    'legend.fontsize': 11,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'figure.dpi': 150,
    'savefig.dpi': 300,
    'savefig.bbox': 'tight',
    'axes.grid': True,
    'grid.alpha': 0.3
})

ALGO_NAME = "SGPSO"
N_PARTICLES = 150
ARCHIVE_SIZE = 300
N_RUNS = 30

# --- Reusable Functions ---

def sample_stability_region():
    """
    Samples (w, c1, c2) using rejection sampling based on the stability triangle:
    0 < w < 1, c1 > 0, c2 > 0, and c1 + c2 < 2(1 + w)
    Uses tighter bounds for better convergence.
    """
    while True:
        w = np.random.uniform(0.1, 0.9)
        c1 = np.random.uniform(0.5, 2.5)
        c2 = np.random.uniform(0.5, 2.5)
        if (c1 + c2) < 2 * (1 + w):
            return w, c1, c2

def polynomial_mutation(X, xl, xu, eta=20):
    """
    Applies polynomial mutation to the population.
    This is critical for escaping local optima (especially ZDT4).
    """
    n, d = X.shape
    prob = 1.0 / d  # Standard mutation probability
    mut_mask = np.random.random((n, d)) < prob
    
    delta = xu - xl
    delta = np.where(delta < 1e-10, 1e-10, delta)
    
    u = np.random.random((n, d))
    delta1 = (X - xl) / delta
    delta2 = (xu - X) / delta
    
    # Ensure delta1 and delta2 are clipped to [0, 1]
    delta1 = np.clip(delta1, 0, 1)
    delta2 = np.clip(delta2, 0, 1)
    
    pow_val = 1.0 / (eta + 1.0)
    
    mask_low = u <= 0.5
    xy = 1.0 - delta1
    val = 2.0 * u + (1.0 - 2.0 * u) * np.power(np.clip(xy, 0, None), eta + 1.0)
    deltaq_low = np.power(np.clip(val, 0, None), pow_val) - 1.0
    
    xy = 1.0 - delta2
    val = 2.0 * (1.0 - u) + 2.0 * (u - 0.5) * np.power(np.clip(xy, 0, None), eta + 1.0)
    deltaq_high = 1.0 - np.power(np.clip(val, 0, None), pow_val)
    
    deltaq = np.where(mask_low, deltaq_low, deltaq_high)
    
    X_mutated = X + deltaq * delta * mut_mask
    return np.clip(X_mutated, xl, xu)

def update_archive(problem, archive, new_pop, max_size=ARCHIVE_SIZE):
    """Updates external archive using pymoo's RankAndCrowding survival."""
    if archive is None or len(archive) == 0:
        combined = new_pop
    else:
        combined = Population.merge(archive, new_pop)
    
    survival = RankAndCrowdingSurvival()
    return survival.do(problem, combined, n_survive=min(len(combined), max_size))

# --- Main SGPSO Logic ---

def run_sgpso(problem_obj, n_particles=N_PARTICLES, n_gen=300, seed=0):
    np.random.seed(seed)
    xl, xu = problem_obj.bounds()
    vmax = 0.2 * (xu - xl)  # Velocity clamping
    
    # Initialize Particles
    X = np.random.uniform(xl, xu, (n_particles, problem_obj.n_var))
    V = np.random.uniform(-0.1 * (xu - xl), 0.1 * (xu - xl), (n_particles, problem_obj.n_var))
    
    # Evaluate initial population
    F = problem_obj.evaluate(X)
    pop = Population.new("X", X, "F", F)
    
    # Initialize PBest and Archive
    pbest_X = np.copy(X)
    pbest_F = np.copy(F)
    archive = Population()
    archive = update_archive(problem_obj, archive, pop)
    
    for gen in range(n_gen):
        w, c1, c2 = sample_stability_region()
        
        # Select Global Leader from archive
        cds = archive.get("crowding")
        if cds is not None and len(cds) > 0:
            # Roulette wheel on crowding distance for diversity
            cds_safe = np.nan_to_num(cds, nan=0.0, posinf=1e6)
            cds_safe = np.clip(cds_safe, 0, 1e6)
            total = np.sum(cds_safe)
            if total > 0:
                probs = cds_safe / total
                gbest_idx = np.random.choice(len(archive), p=probs)
            else:
                gbest_idx = np.random.randint(len(archive))
        else:
            gbest_idx = np.random.randint(len(archive))
        gbest = archive[gbest_idx].x
        
        for i in range(n_particles):
            # Ring Topology (radius 3 for better information flow)
            nb_idx = np.arange(i - 3, i + 4) % n_particles
            lbest_idx_in_nb = np.argmin(np.sum(pbest_F[nb_idx], axis=1))
            lbest = pbest_X[nb_idx[lbest_idx_in_nb]]
            
            r1, r2 = np.random.random(problem_obj.n_var), np.random.random(problem_obj.n_var)
            V[i] = (w * V[i] + 
                    c1 * r1 * (pbest_X[i] - X[i]) + 
                    c2 * r2 * (gbest - X[i]))
            
            # Velocity clamping
            V[i] = np.clip(V[i], -vmax, vmax)
            X[i] = np.clip(X[i] + V[i], xl, xu)
            
        # Apply mutation for diversity
        X = polynomial_mutation(X, xl, xu, eta=20)
        
        F = problem_obj.evaluate(X)
        pop = Population.new("X", X, "F", F)
        
        # PBest Update (dominance-based with tie-breaking)
        for i in range(n_particles):
            # New dominates old
            if np.all(F[i] <= pbest_F[i]) and np.any(F[i] < pbest_F[i]):
                pbest_X[i] = np.copy(X[i])
                pbest_F[i] = np.copy(F[i])
            # Non-dominated: pick randomly (maintains diversity)
            elif not (np.all(pbest_F[i] <= F[i]) and np.any(pbest_F[i] < F[i])):
                if np.random.random() < 0.5:
                    pbest_X[i] = np.copy(X[i])
                    pbest_F[i] = np.copy(F[i])
                
        archive = update_archive(problem_obj, archive, pop)

    return archive

# --- Pareto Front Plotting (Publication Quality) ---

def plot_pareto_comparison_2d(pf, obtained_F, algo_name, func_name, output_path, color='#2196F3'):
    """Publication-quality 2D Pareto front comparison plot."""
    fig, ax = plt.subplots(figsize=(8, 6))
    
    if pf is not None:
        sorted_pf = pf[pf[:, 0].argsort()]
        ax.plot(sorted_pf[:, 0], sorted_pf[:, 1], color='black', lw=2.0, 
                label='True Pareto Front', alpha=0.85, zorder=5)
    
    ax.scatter(obtained_F[:, 0], obtained_F[:, 1], facecolor='none', 
              edgecolor=color, s=40, linewidths=1.2, 
              label=f'{algo_name} Obtained', alpha=0.85, zorder=10)
    
    ax.set_xlabel(r'$f_1$')
    ax.set_ylabel(r'$f_2$')
    ax.set_title(f'{algo_name} vs True Pareto Front — {func_name}')
    ax.legend(loc='best', framealpha=0.9)
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

def plot_pareto_comparison_3d(pf, obtained_F, algo_name, func_name, output_path, color='#2196F3'):
    """Publication-quality 3D Pareto front comparison plot."""
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    if pf is not None:
        ax.scatter(pf[:, 0], pf[:, 1], pf[:, 2], c='gray', s=8, 
                  label='True Pareto Front', alpha=0.15, zorder=1)
    
    ax.scatter(obtained_F[:, 0], obtained_F[:, 1], obtained_F[:, 2], 
             facecolor='none', edgecolor=color, s=30, linewidths=1.0,
             label=f'{algo_name} Obtained', alpha=0.8, zorder=10)
    
    ax.set_xlabel(r'$f_1$', labelpad=10)
    ax.set_ylabel(r'$f_2$', labelpad=10)
    ax.set_zlabel(r'$f_3$', labelpad=10)
    ax.set_title(f'{algo_name} vs True Pareto Front — {func_name}')
    ax.legend(loc='best', framealpha=0.9)
    ax.view_init(elev=25, azim=45)
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# --- Experiment Execution ---

def main():
    benchmarks = ["zdt1", "zdt2", "zdt3", "zdt4", "zdt6", 
                  "wfg1", "wfg2", "wfg3", "wfg4", "wfg5", "wfg6", "wfg7", "wfg8", "wfg9"]
    
    all_results = []
    
    for b_name in benchmarks:
        print(f"\n{'='*60}")
        print(f"Processing Function: {b_name.upper()} ({ALGO_NAME})")
        print(f"{'='*60}")
        output_dir = f"./results/{ALGO_NAME}/{b_name}/"
        os.makedirs(output_dir, exist_ok=True)
        
        # Problem setup
        is_wfg = b_name.lower().startswith("wfg")
        if is_wfg:
            problem = get_problem(b_name, n_var=24, n_obj=3, k=4)
        else:
            problem = get_problem(b_name)
        
        # Adaptive generation count
        n_gen = 400 if is_wfg else 300
        if b_name.lower() == 'zdt4':
            n_gen = 500  # ZDT4 needs more iterations due to multimodality
            
        pf = problem.pareto_front()
        
        # HV reference point — problem-aware
        if is_wfg:
            ref_point = np.array([3.0, 5.0, 7.0])  # WFG-specific
        else:
            ref_point = np.ones(problem.n_obj) * 2.5
        
        run_results = []
        best_igd = np.inf
        best_F = None
        
        for run in range(N_RUNS):
            print(f"  Trial {run + 1}/{N_RUNS} running...", end="\r")
            res_archive = run_sgpso(problem, n_gen=n_gen, seed=run)
            F = res_archive.get("F")
            
            if pf is not None:
                igd = IGD(pf).do(F)
                hv = HV(ref_point=ref_point).do(F)
            else:
                igd, hv = np.nan, np.nan
                
            run_results.append({"run": run + 1, "IGD": igd, "HV": hv})
            
            # Track best run for plotting
            if igd < best_igd:
                best_igd = igd
                best_F = F.copy()
            
        print(f"\n  [Done] {b_name.upper()} — {N_RUNS} trials completed.")
        
        df = pd.DataFrame(run_results)
        df.to_csv(f"{output_dir}metrics.csv", index=False)
        
        igd_mean, igd_std = df['IGD'].mean(), df['IGD'].std()
        hv_mean, hv_std = df['HV'].mean(), df['HV'].std()
        
        print(f"  Summary for {b_name.upper()}:")
        print(f"    IGD: Mean = {igd_mean:.6f}, Std = {igd_std:.6f}")
        print(f"    HV:  Mean = {hv_mean:.6f}, Std = {hv_std:.6f}")
        
        all_results.append({
            'Function': b_name.upper(),
            'IGD_Mean': igd_mean, 'IGD_Std': igd_std,
            'HV_Mean': hv_mean, 'HV_Std': hv_std
        })
        
        # --- Pareto Front Comparison Plot (Best Run) ---
        if problem.n_obj == 2:
            plot_pareto_comparison_2d(pf, best_F, ALGO_NAME, b_name.upper(),
                                     f"{output_dir}pareto_front_comparison.png", color='#2196F3')
        else:
            plot_pareto_comparison_3d(pf, best_F, ALGO_NAME, b_name.upper(),
                                     f"{output_dir}pareto_front_comparison.png", color='#2196F3')
    
    # --- Summary Table ---
    print(f"\n{'='*80}")
    print(f"FINAL SUMMARY TABLE — {ALGO_NAME}")
    print(f"{'='*80}")
    summary_df = pd.DataFrame(all_results)
    summary_df.to_csv(f"./results/{ALGO_NAME}/summary.csv", index=False)
    print(summary_df.to_string(index=False))

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Processing Function: ZDT1 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] ZDT1 — 30 trials completed.
#   Summary for ZDT1:
#     IGD: Mean = 0.002400, Std = 0.001978
#     HV:  Mean = 5.911285, Std = 0.006949
# ============================================================
# Processing Function: ZDT2 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] ZDT2 — 30 trials completed.
#   Summary for ZDT2:
#     IGD: Mean = 0.009879, Std = 0.029515
#     HV:  Mean = 5.495994, Std = 0.230505
# ============================================================
# Processing Function: ZDT3 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] ZDT3 — 30 trials completed.
#   Summary for ZDT3:
#     IGD: Mean = 0.005457, Std = 0.005871
#     HV:  Mean = 7.409053, Std = 0.060212
# ============================================================
# Processing Function: ZDT4 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] ZDT4 — 30 trials completed.
#   Summary for ZDT4:
#     IGD: Mean = 17.202899, Std = 2.774308
#     HV:  Mean = 0.000000, Std = 0.000000
# ============================================================
# Processing Function: ZDT6 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] ZDT6 — 30 trials completed.
#   Summary for ZDT6:
#     IGD: Mean = 0.318580, Std = 0.192728
#     HV:  Mean = 4.303472, Std = 0.460232
# ============================================================
# Processing Function: WFG1 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG1 — 30 trials completed.
#   Summary for WFG1:
#     IGD: Mean = 1.447696, Std = 0.030780
#     HV:  Mean = 44.288796, Std = 1.149049
# ============================================================
# Processing Function: WFG2 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG2 — 30 trials completed.
#   Summary for WFG2:
#     IGD: Mean = 0.255607, Std = 0.061307
#     HV:  Mean = 94.076146, Std = 2.106735
# ============================================================
# Processing Function: WFG3 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG3 — 30 trials completed.
#   Summary for WFG3:
#     IGD: Mean = 0.296621, Std = 0.043331
#     HV:  Mean = 66.822540, Std = 1.520071
# ============================================================
# Processing Function: WFG4 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG4 — 30 trials completed.
#   Summary for WFG4:
#     IGD: Mean = 0.264621, Std = 0.044302
#     HV:  Mean = 68.450849, Std = 1.638649
# ============================================================
# Processing Function: WFG5 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG5 — 30 trials completed.
#   Summary for WFG5:
#     IGD: Mean = 0.408336, Std = 0.132409
#     HV:  Mean = 59.801194, Std = 5.951796
# ============================================================
# Processing Function: WFG6 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG6 — 30 trials completed.
#   Summary for WFG6:
#     IGD: Mean = 0.361030, Std = 0.072870
#     HV:  Mean = 64.660570, Std = 3.328235
# ============================================================
# Processing Function: WFG7 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG7 — 30 trials completed.
#   Summary for WFG7:
#     IGD: Mean = 0.356022, Std = 0.027067
#     HV:  Mean = 65.480336, Std = 1.288003
# ============================================================
# Processing Function: WFG8 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG8 — 30 trials completed.
#   Summary for WFG8:
#     IGD: Mean = 0.605920, Std = 0.078370
#     HV:  Mean = 52.663287, Std = 3.146660
# ============================================================
# Processing Function: WFG9 (SGPSO)
# ============================================================
#   Trial 30/30 running...
#   [Done] WFG9 — 30 trials completed.
#   Summary for WFG9:
#     IGD: Mean = 0.283456, Std = 0.037191
#     HV:  Mean = 65.989134, Std = 1.838776
# ================================================================================
# FINAL SUMMARY TABLE — SGPSO
# ================================================================================
# Function  IGD_Mean  IGD_Std   HV_Mean   HV_Std
#     ZDT1  0.002400 0.001978  5.911285 0.006949
#     ZDT2  0.009879 0.029515  5.495994 0.230505
#     ZDT3  0.005457 0.005871  7.409053 0.060212
#     ZDT4 17.202899 2.774308  0.000000 0.000000
#     ZDT6  0.318580 0.192728  4.303472 0.460232
#     WFG1  1.447696 0.030780 44.288796 1.149049
#     WFG2  0.255607 0.061307 94.076146 2.106735
#     WFG3  0.296621 0.043331 66.822540 1.520071
#     WFG4  0.264621 0.044302 68.450849 1.638649
#     WFG5  0.408336 0.132409 59.801194 5.951796
#     WFG6  0.361030 0.072870 64.660570 3.328235
#     WFG7  0.356022 0.027067 65.480336 1.288003
#     WFG8  0.605920 0.078370 52.663287 3.146660
#     WFG9  0.283456 0.037191 65.989134 1.838776
